# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def tropfen(anzahl):
    quad = np.random.uniform(-1, 1, (anzahl,2))
    print(quad)
    print("Quad shape",quad.shape)
    inside = np.sqrt((quad[:,0]**2) + (quad[:,1]**2)) < 1
    inside_number = sum(inside)
    pi_approx = (inside_number*4)/anzahl
    print("pi approximated",pi_approx)

# %%
tropfen(10000)
# Out:
# [[ 0.1974602   0.5565783 ]
#  [ 0.86568114 -0.16868516]
#  [ 0.19156173  0.71686584]
#  ...
#  [-0.32259125 -0.07000498]
#  [-0.47602462 -0.05655723]
#  [-0.13541536 -0.72143907]]
# Quad shape (10000, 2)
# pi approximated 3.1468
